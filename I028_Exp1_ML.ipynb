# %% [markdown]
# Name - Aditya Kothari
# Roll no. - I028

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
#1
df = pd.read_excel('/content/indian_food.csv')

# %%
df
# Out:
#                name                                        ingredients  \
# 0        Balu shahi                    Maida flour, yogurt, oil, sugar
# 1            Boondi                            Gram flour, ghee, sugar
# 2    Gajar ka halwa       Carrots, milk, sugar, ghee, cashews, raisins
# 3            Ghevar  Flour, ghee, kewra, milk, clarified butter, su...
# 4       Gulab jamun  Milk powder, plain flour, baking powder, ghee,...
# ..              ...                                                ...
# 250       Til Pitha            Glutinous rice, black sesame seeds, gur
# 251         Bebinca  Coconut milk, egg yolks, clarified butter, all...
# 252          Shufta  Cottage cheese, dry dates, dried rose petals, ...
# 253       Mawa Bati  Milk powder, dry fruits, arrowroot powder, all...
# 254          Pinaca  Brown rice, fennel seeds, grated coconut, blac...
#
#            diet  prep_time  cook_time flavor_profile   course  \
# ...

# %%
#2
size = df.size
shape = df.shape
data_types = df.dtypes
print("Size : ",size,"\n")
print("Shape: ",shape,"\n")
data_types
# Out:
# Size :  2805
#
# Shape:  (255, 11)
# name                 object
# ingredients          object
# diet                 object
# prep_time             int64
# cook_time             int64
# flavor_profile       object
# course               object
# state                object
# region               object
# Total_Time            int64
# Total_Ingredients     int64
# dtype: object

# %%
#3
unique_value = df["name"].nunique()
print("Total no. of dishes =",unique_value)
# Out:
# Total no. of dishes = 255

# %%
#4
#There are 8 features and 1 label

# %%
#5
describe_data = df.describe()
describe_data
# Out:
#         prep_time   cook_time  Total_Time  Total_Ingredients
# count  255.000000  255.000000  255.000000         255.000000
# mean    31.223529   34.639216   65.862745           4.454902
# std     72.502844   48.185452   92.593307           1.205681
# min      0.000000    0.000000    0.000000           2.000000
# 25%     10.000000   20.000000   30.000000           4.000000
# 50%     10.000000   30.000000   50.000000           5.000000
# 75%     20.000000   40.000000   60.000000           5.000000
# max    500.000000  720.000000  730.000000          10.000000

# %%
#6
df.fillna('NaN',inplace = True)
df.replace(-1,0,inplace=True)

# %%
df
# Out:
#                name                                        ingredients  \
# 0        Balu shahi                    Maida flour, yogurt, oil, sugar
# 1            Boondi                            Gram flour, ghee, sugar
# 2    Gajar ka halwa       Carrots, milk, sugar, ghee, cashews, raisins
# 3            Ghevar  Flour, ghee, kewra, milk, clarified butter, su...
# 4       Gulab jamun  Milk powder, plain flour, baking powder, ghee,...
# ..              ...                                                ...
# 250       Til Pitha            Glutinous rice, black sesame seeds, gur
# 251         Bebinca  Coconut milk, egg yolks, clarified butter, all...
# 252          Shufta  Cottage cheese, dry dates, dried rose petals, ...
# 253       Mawa Bati  Milk powder, dry fruits, arrowroot powder, all...
# 254          Pinaca  Brown rice, fennel seeds, grated coconut, blac...
#
#            diet  prep_time  cook_time flavor_profile   course  \
# ...

# %%
#7
#There are 2 numerical feature and 6 categorical fetaures

# %%
#8
print(df['name'].value_counts())
# Out:
# Balu shahi         1
# Chorafali          1
# Vada               1
# Chicken Varuval    1
# Upma               1
#                   ..
# Kachori            1
# Kadai paneer       1
# Kadhi pakoda       1
# Karela bharta      1
# Pinaca             1
# Name: name, Length: 255, dtype: int64

# %%
#8
print(df['ingredients'].value_counts())
# Out:
# Gram flour, ghee, sugar                                                   2
# Chhena, sugar, ghee                                                       2
# Arbi ke patte, sesame seeds, gur, bengal gram flour, imli                 2
# Green chilies, lemon juice, chili powder, boiled potatoes                 1
# Whole wheat rava, chia seed, lemon, edible gum, litre milk                1
#                                                                          ..
# Cottage cheese, bell peppers, gravy, garam masala, cashew nuts            1
# Besan, garam masala powder, gram flour, ginger, curry leaves              1
# Bitter gourd, fennel, garam masala powder, chili powder, amchur powder    1
# Moong dal, green peas, ginger, tomato, green chili                        1
# Brown rice, fennel seeds, grated coconut, black pepper, ginger powder     1
# Name: ingredients, Length: 252, dtype: int64

# %%
#8
print(df['diet'].value_counts())
# Out:
# vegetarian        226
# non vegetarian     29
# Name: diet, dtype: int64

# %%
#8
print(df['prep_time'].value_counts())
# Out:
# 10     98
# 20     40
# 0      30
# 15     22
# 5      16
# 30     12
# 45      5
# 120     5
# 25      5
# 240     4
# 40      3
# 360     3
# 60      2
# 180     2
# 80      1
# 500     1
# 150     1
# 480     1
# 495     1
# 70      1
# 35      1
# 12      1
# Name: prep_time, dtype: int64

# %%
#8
print(df['cook_time'].value_counts())
# Out:
# 30     59
# 20     42
# 0      28
# 40     27
# 60     22
# 45     15
# 25     13
# 50     10
# 35      9
# 90      7
# 10      7
# 15      5
# 120     3
# 5       3
# 75      1
# 720     1
# 55      1
# 2       1
# 6       1
# Name: cook_time, dtype: int64

# %%
#8
print(df['flavor_profile'].value_counts())
# Out:
# spicy     133
# sweet      88
# 0          29
# bitter      4
# sour        1
# Name: flavor_profile, dtype: int64

# %%
#8
print(df['course'].value_counts())
# Out:
# main course    129
# dessert         85
# snack           39
# starter          2
# Name: course, dtype: int64

# %%
#8
print(df['state'].value_counts())
# Out:
# Gujarat            35
# Punjab             32
# Maharashtra        30
# West Bengal        24
# 0                  24
# Assam              21
# Tamil Nadu         20
# Andhra Pradesh     10
# Uttar Pradesh       9
# Kerala              8
# Odisha              7
# Karnataka           6
# Rajasthan           6
# Telangana           5
# Bihar               3
# Goa                 3
# Manipur             2
# Jammu & Kashmir     2
# Madhya Pradesh      2
# Uttarakhand         1
# Tripura             1
# Nagaland            1
# NCT of Delhi        1
# Chhattisgarh        1
# Haryana             1
# Name: state, dtype: int64

# %%
#8
print(df['region'].value_counts())
# Out:
# West          74
# South         59
# North         49
# East          31
# North East    25
# 0             13
# Central        3
# NaN            1
# Name: region, dtype: int64

# %%
#9
df['Total_Time'] = df["cook_time"] + df["prep_time"]

# %%
df
# Out:
#                name                                        ingredients  \
# 0        Balu shahi                    Maida flour, yogurt, oil, sugar
# 1            Boondi                            Gram flour, ghee, sugar
# 2    Gajar ka halwa       Carrots, milk, sugar, ghee, cashews, raisins
# 3            Ghevar  Flour, ghee, kewra, milk, clarified butter, su...
# 4       Gulab jamun  Milk powder, plain flour, baking powder, ghee,...
# ..              ...                                                ...
# 250       Til Pitha            Glutinous rice, black sesame seeds, gur
# 251         Bebinca  Coconut milk, egg yolks, clarified butter, all...
# 252          Shufta  Cottage cheese, dry dates, dried rose petals, ...
# 253       Mawa Bati  Milk powder, dry fruits, arrowroot powder, all...
# 254          Pinaca  Brown rice, fennel seeds, grated coconut, blac...
#
#            diet  prep_time  cook_time flavor_profile   course  \
# ...

# %%
#10 
df["Total_Ingredients"] = df.ingredients.str.count(",") + 1

# %%
df
# Out:
#                name                                        ingredients  \
# 0        Balu shahi                    Maida flour, yogurt, oil, sugar
# 1            Boondi                            Gram flour, ghee, sugar
# 2    Gajar ka halwa       Carrots, milk, sugar, ghee, cashews, raisins
# 3            Ghevar  Flour, ghee, kewra, milk, clarified butter, su...
# 4       Gulab jamun  Milk powder, plain flour, baking powder, ghee,...
# ..              ...                                                ...
# 250       Til Pitha            Glutinous rice, black sesame seeds, gur
# 251         Bebinca  Coconut milk, egg yolks, clarified butter, all...
# 252          Shufta  Cottage cheese, dry dates, dried rose petals, ...
# 253       Mawa Bati  Milk powder, dry fruits, arrowroot powder, all...
# 254          Pinaca  Brown rice, fennel seeds, grated coconut, blac...
#
#            diet  prep_time  cook_time flavor_profile   course  \
# ...

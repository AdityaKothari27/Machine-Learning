# %% [markdown]
# Name - Aditya Kothari
#
# Roll no. - I028
#
# Batch - B1

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# 1. Read “seeds.csv” file into data frame.

# %%
df=pd.read_csv("/content/seeds.csv")
df
# Out:
#       Area  Perimeter  Compactness  Kernel.Length  Kernel.Width  \
# 0    15.26      14.84       0.8710          5.763         3.312
# 1    14.88      14.57       0.8811          5.554         3.333
# 2    14.29      14.09       0.9050          5.291         3.337
# 3    13.84      13.94       0.8955          5.324         3.379
# 4    16.14      14.99       0.9034          5.658         3.562
# ..     ...        ...          ...            ...           ...
# 194  12.19      13.20       0.8783          5.137         2.981
# 195  11.23      12.88       0.8511          5.140         2.795
# 196  13.20      13.66       0.8883          5.236         3.232
# 197  11.84      13.21       0.8521          5.175         2.836
# 198  12.30      13.34       0.8684          5.243         2.974
#
#      Asymmetry.Coeff  Kernel.Groove  Type
# 0              2.221          5.220     1
# 1              1.018          4.956     1
# 2              2.699          4.825     1
# ...

# %% [markdown]
# 2. Explore the dataset by using head and describe.

# %%
df.head()
# Out:
#     Area  Perimeter  Compactness  Kernel.Length  Kernel.Width  \
# 0  15.26      14.84       0.8710          5.763         3.312
# 1  14.88      14.57       0.8811          5.554         3.333
# 2  14.29      14.09       0.9050          5.291         3.337
# 3  13.84      13.94       0.8955          5.324         3.379
# 4  16.14      14.99       0.9034          5.658         3.562
#
#    Asymmetry.Coeff  Kernel.Groove  Type
# 0            2.221          5.220     1
# 1            1.018          4.956     1
# 2            2.699          4.825     1
# 3            2.259          4.805     1
# 4            1.355          5.175     1

# %%
df.describe()
# Out:
#              Area   Perimeter  Compactness  Kernel.Length  Kernel.Width  \
# count  199.000000  199.000000   199.000000     199.000000    199.000000
# mean    14.918744   14.595829     0.870811       5.643151      3.265533
# std      2.919976    1.310445     0.023320       0.443593      0.378322
# min     10.590000   12.410000     0.808100       4.899000      2.630000
# 25%     12.330000   13.470000     0.857100       5.267000      2.954500
# 50%     14.430000   14.370000     0.873400       5.541000      3.245000
# 75%     17.455000   15.805000     0.886800       6.002000      3.564500
# max     21.180000   17.250000     0.918300       6.675000      4.033000
#
#        Asymmetry.Coeff  Kernel.Groove        Type
# count       199.000000     199.000000  199.000000
# mean          3.699217       5.420653    1.994975
# std           1.471102       0.492718    0.813382
# min           0.765100       4.519000    1.000000
# 25%           2.570000       5.046000    1.000000
# ...

# %% [markdown]
# 3. Find the number of samples per type. Plot a histplot for the count.

# %%
df['Type'].value_counts(ascending=True)
# Out:
# 3    65
# 1    66
# 2    68
# Name: Type, dtype: int64

# %%
sns.histplot(data=df, x='Type')

# %% [markdown]
# 4. Plot a scatter plot for Kernel Width vs Length. Write your inference.

# %%
x=df['Kernel.Length']
y=df['Kernel.Width']
plt.scatter(x,y)

# %% [markdown]
# There is a linear relationship between Kernel.length and Kernel.Width. As the length increases, the width also increases.

# %%
df.plot(kind = 'scatter',x='Kernel.Length',y='Kernel.Width')

# %% [markdown]
# 5. Plot a Jointplot to understand relation between Perimeter and Compactness. Write your inference.

# %%
y=df['Compactness']
x=df["Perimeter"]
sns.jointplot(x,y)
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# Perimeter and Compactness aren't related as there is no correlation between them.

# %% [markdown]
# 6. Plot a Scatter plot to compare Perimeter and Compactness. Different type should have different colours. (hint use legend).

# %%
 sns.FacetGrid(df, hue='Type',height=5).map(plt.scatter,'Perimeter','Compactness').add_legend()

# %% [markdown]
# 7. Plot a Box plot to understand correlation between compactness and type.

# %%
x=df['Compactness']
x=df['Type']
sns.boxplot(x,y)
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.boxplot(y='Compactness',x='Type',data=df)

# %% [markdown]
#  1) We have compared compactness with 3 types given in the dataset.
#
#   2) For Type 1: there exist points which exist outside the lower and upper whiskers. Therefore, it contains outliers.
#
#   3) Medians are varying.
#
#   4) Type 1 is more concentrated, i.e. it has minimum IQR.

# %% [markdown]
# 8.	Plot a Box & Strip plots to understand correlation between compactness and type. State your inference.

# %%
y=df['Compactness']
x=df['Type']
sns.boxplot(x,y)
sns.stripplot(x,y,jitter=True)
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# 1) The points lying inside the box are in the IQR.
#
# 2) The points lying above and below the box but within the respective whiskers are the First and Third Quartiles.
#
# 3)The scattered dots outside the min and max boundaries represent the outliers.

# %% [markdown]
# 9. Plot a Box & Strip plots to understand correlation between perimeter and type.

# %%
y=df['Perimeter']
x=df['Type']
sns.boxplot(x,y)
sns.stripplot(x,y)
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# 10. Plot a Violin and strip subplots to understand correlation between compactness and type. State your inference

# %%
y=df['Compactness']
x=df['Type']
sns.violinplot(x,y)
sns.stripplot(x,y,jitter=True)
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
#  1) The greather the IQR of the Type, the longer is the shape of the violin.
#
#   2) It tells the distribution of the sample.

# %% [markdown]
# 11. Plot a Kernel Density Estimation plots to understand correlation between compactness and type. State your inference

# %%
y=df['Compactness']
x=df['Type']
sns.kdeplot(x,y)
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.FacetGrid(df,hue='Type',height=5).map(sns.kdeplot,'Compactness').add_legend()

# %% [markdown]
#   1) Type 3 is separable.
#
#   2) Type 1 and 2 are overlapping.
#
#   3) Deviation for Type 3 along x axis is more unlike Type 1 and 2.
#
#   4) Greater the deviation, greater is the IQR.

# %% [markdown]
# 12. Plot a pair plot to understand all characteristics with type being the main parameter.

# %%
sns.pairplot(df,hue='Type',height=3, diag_kind='hist')

# %% [markdown]
# 13. Plot a pair plot to understand all characteristics with type being the main parameter. (the main parameter, with KDE instead of histogram in diagonal subplots)

# %%
sns.pairplot(df,hue='Type',height=3).add_legend()

# %% [markdown]
# 1) Diagonal kind is mentioned as histogram and hence all features with themselves.
#
#   2) If Diagonal kind is not mentioned,only KDE is plotted.
#
#   3) The parameters which are correlated with other entities/parameters include:
#
#   {(Area, Perimeter ), (Area, Compactness), (Area, Length), (Area, Width), (Area, Asymmetry Coeff), (Area, Kernel,Grove)}, etc.
#
# Uncorrelated Entities include:
#
#   {(Asymmetry, Kernel.Width)(Compactness, Kernel.Grove)}, etc.

# %% [markdown]
# 14. An Andrews curve to display separability of data according to Type.

# %%
pd.plotting.andrews_curves(df,class_column='Type')

# %%
x=[2,8,10]
y=[11,16,9]
x2=[2,3,6]
y2=[4,16,9]

# %%
plt.bar(x,y)
# Out:
# <BarContainer object of 3 artists>

# %%
plt.bar(x2,y2)
# Out:
# <BarContainer object of 3 artists>
